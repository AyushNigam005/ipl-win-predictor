# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
match.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
total_score_df = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bengaluru',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Lucknow Super Giants',
    'Gujarat Titans'
]

team_name_updates = {
    'Delhi Daredevils': 'Delhi Capitals',
    'Deccan Chargers': 'Sunrisers Hyderabad',
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru',
    'Kings XI Punjab': 'Punjab Kings'
}

match_df['team1'] = match_df['team1'].replace(team_name_updates)
match_df['team2'] = match_df['team2'].replace(team_name_updates)
match_df['toss_winner'] = match_df['toss_winner'].replace(team_name_updates) 
match_df['winner'] = match_df['winner'].replace(team_name_updates)

teams_to_remove = ['Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants', 
                   'Rising Pune Supergiant', 'Gujarat Lions']

match_df = match_df[~match_df['team1'].isin(teams_to_remove) & ~match_df['team2'].isin(teams_to_remove)]

match_df = match_df[
    match_df['team1'].isin(teams) & 
    match_df['team2'].isin(teams) & 
    match_df['toss_winner'].isin(teams) ]


print("Updated match dataset shape:", match_df.shape)



match_df.head()
# Out:
# Updated match dataset shape: (980, 22)
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
# ...

# %%
match_df.shape
# Out:
# (980, 22)

# %%
print(match_df.columns)
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %% [markdown]
# MATCHES WIN BY DLS IS REMOVED

# %%
match_df['method'] = match_df['method'].notna().astype(int)
match_df = match_df[match_df['method'] == 0]

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df.shape
# Out:
# (963, 22)

# %%
match_df = match_df[['match_id', 'city', 'winner', 'total_runs']]
match_df.merge(delivery, on='match_id')
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 0         335982  Bangalore  Kolkata Knight Riders           222       1
# 1         335982  Bangalore  Kolkata Knight Riders           222       1
# 2         335982  Bangalore  Kolkata Knight Riders           222       1
# 3         335982  Bangalore  Kolkata Knight Riders           222       1
# 4         335982  Bangalore  Kolkata Knight Riders           222       1
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df = match_df.merge(delivery, on='match_id')
delivery_df = delivery_df[delivery_df['inning'] == 2]

delivery_df['batting_team'] = delivery_df['batting_team'].replace(team_name_updates)
delivery_df['bowling_team'] = delivery_df['bowling_team'].replace(team_name_updates)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df.shape
# Out:
# (111721, 20)

# %%
# Ensure 'total_runs_y' is numeric
delivery_df['total_runs_y'] = pd.to_numeric(delivery_df['total_runs_y'], errors='coerce')

# Now calculate cumulative sum groupwise
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['balls_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
# Step 1: Replace NaN with 0 (indicating no dismissal)
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna(0)

# Step 2: Convert actual dismissed player names to 1, else 0
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x: 0 if x == 0 else 1)

# Step 3: Convert to integer
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype(int)

# Step 4: Compute remaining wickets directly
delivery_df['wickets'] = 10 - delivery_df.groupby('match_id')['player_dismissed'].cumsum()

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           113       2
# 230978   1426312    Chennai  Kolkata Knight Riders           113       2
# 230979   1426312    Chennai  Kolkata Knight Riders           113       2
# 230980   1426312    Chennai  Kolkata Knight Riders           113       2
# 230981   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                  batting_team  bowling_team        city  runs_left  \
# 108857  Kolkata Knight Riders  Punjab Kings  Chandigarh         34
#
#         balls_left  wickets  total_runs_x       crr   rrr  result
# 108857          50        8           138  8.914286  4.08       1

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team           bowling_team       city  \
# 178716        Kolkata Knight Riders    Chennai Super Kings     Mumbai
# 67153   Royal Challengers Bengaluru    Sunrisers Hyderabad  Bangalore
# 104833               Delhi Capitals    Chennai Super Kings     Raipur
# 100920  Royal Challengers Bengaluru  Kolkata Knight Riders  Bangalore
# 181594  Royal Challengers Bengaluru       Rajasthan Royals     Mumbai
# ...                             ...                    ...        ...
# 195005             Rajasthan Royals    Chennai Super Kings     Mumbai
# 181423          Sunrisers Hyderabad   Lucknow Super Giants     Mumbai
# 4159                   Punjab Kings    Sunrisers Hyderabad  Hyderabad
# 211405               Mumbai Indians   Lucknow Super Giants    Lucknow
# 182888  Royal Challengers Bengaluru         Mumbai Indians       Pune
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8034553134937586

# %%
pipe.predict_proba(X_test)[2]
# Out:
# array([0.17231307, 0.82768693])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df, match_id, pipe1):
    match = x_df[x_df['match_id'] == match_id]

    # Sort to ensure proper order
    match = match.sort_values(['over', 'ball'])

    # Get last delivery of each over
    match_last_ball_per_over = match.groupby('over').tail(1)

    # Ensure the final delivery of the match is included (e.g., game ended in 15.4)
    final_delivery = match.tail(1)

    # Combine and drop duplicates (in case final_delivery already in the group)
    match = pd.concat([match_last_ball_per_over, final_delivery]).drop_duplicates().reset_index(drop=True)

    # Prepare features
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]

    if temp_df.empty:
        print(f"No valid data available for match_id={match_id}")
        return pd.DataFrame(), None

    # Predict probabilities
    result = pipe1.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0] * 100, 1)
    temp_df['win'] = np.round(result.T[1] * 100, 1)

    temp_df['end_of_over'] = range(1, temp_df.shape[0] + 1)

    # Compute progression runs
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0, target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)

    # Compute wickets in each over
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0, 10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]

    print("Target -", target)

    # Return only needed columns
    temp_df = temp_df[['end_of_over', 'runs_after_over', 'wickets_in_over', 'lose', 'win']]
    return temp_df, target

# %%
temp_df,target = match_progression(delivery_df,1426312,pipe)
temp_df
# Out:
# Target - 113
#     end_of_over  runs_after_over  wickets_in_over  lose   win
# 0             1                5                0   8.6  91.4
# 1             2               12                1   9.1  90.9
# 2             3               20                0   3.3  96.7
# 3             4                9                0   3.1  96.9
# 4             5                6                0   2.7  97.3
# 5             6               20                0   1.1  98.9
# 6             7               12                0   0.7  99.3
# 7             8                9                0   0.6  99.4
# 8             9               13                1   0.6  99.4
# 9            10                5                0   0.6  99.4
# 10           11                3                0   0.6  99.4

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})
pred_df
# Out:
#         Actual Value  Predicted Value  Difference
# 7256               0                0           0
# 52136              0                1          -1
# 6604               1                1           0
# 201312             1                0           1
# 111265             0                1          -1
# ...              ...              ...         ...
# 212641             0                0           0
# 178282             1                1           0
# 221471             1                0           1
# 222081             1                1           0
# 183872             0                0           0
#
# [21069 rows x 3 columns]
